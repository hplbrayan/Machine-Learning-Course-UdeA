# %%
import pandas as pd
import numpy as np

from scipy.stats import skewtest, levene

import matplotlib.pylab as plt
import seaborn as sbn

# %%
colss = pd.read_csv(filepath_or_buffer="./icfes_columns_names.csv")
cols  = [colss.values[i][0] for i in range(len(colss))]

# %%
# Out:
# 60

# %%
#path = "./icfes_data.csv"
path = "https://www.kaggle.com/datasets/sorelyss/icfes-colombia-20182021?select=icfes_data.csv"
limit = "?$limit=1000"

df = pd.read_csv(filepath_or_buffer=path+limit, names=cols)
df
# Out:
#                                     ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD  \
# 0                                      <!DOCTYPE html>               NaN
# 1                                     <html lang="en">               NaN
# 2                                               <head>               NaN
# 3      <title>ICFES Colombia 2018-2021 | Kaggle</ti...               NaN
# 4                             <meta charset="utf-8" />               NaN
# ..                                                 ...               ...
# 160                                          </script>               NaN
# 161                                             </div>               NaN
# 162                                            </main>               NaN
# 163                                            </body>               NaN
# 164                                            </html>               NaN
#
#     ESTU_GENERO ESTU_FECHANACIMIENTO PERIODO ESTU_ESTUDIANTE ESTU_PAIS_RESIDE  \
# ...

# %%
df.shape
# Out:
# (165, 83)
